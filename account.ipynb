# %%
from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager

api_key=''
api_secret=''
client = Client(api_key, api_secret)

info = client.get_account()
info
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00100000',
#   'taker': '0.00100000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'preventSor': False,
#  'updateTime': 1773641701122,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %%
balance = client.futures_account()
balance
# Out:
# {'feeTier': 0,
#  'canTrade': True,
#  'canDeposit': True,
#  'canWithdraw': True,
#  'feeBurn': True,
#  'tradeGroupId': -1,
#  'updateTime': 0,
#  'multiAssetsMargin': False,
#  'totalInitialMargin': '21.87298282',
#  'totalMaintMargin': '0.08749193',
#  'totalWalletBalance': '278.60835018',
#  'totalUnrealizedProfit': '-1.36941717',
#  'totalMarginBalance': '277.23893301',
#  'totalPositionInitialMargin': '21.87298282',
#  'totalOpenOrderInitialMargin': '0.00000000',
#  'totalCrossWalletBalance': '278.60835018',
#  'totalCrossUnPnl': '-1.36941717',
#  'availableBalance': '255.36446736',
#  'maxWithdrawAmount': '255.36446736',
#  'assets': [{'asset': 'FDUSD',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
# ...

# %%
pos=client.futures_position_information()
pos
# Out:
# [{'symbol': 'ETHUSDT',
#   'positionSide': 'BOTH',
#   'positionAmt': '0.010',
#   'entryPrice': '2324.24',
#   'breakEvenPrice': '2325.40212',
#   'markPrice': '2187.25341860',
#   'unRealizedProfit': '-1.36986581',
#   'liquidationPrice': '0',
#   'isolatedMargin': '0',
#   'notional': '21.87253418',
#   'marginAsset': 'USDT',
#   'isolatedWallet': '0',
#   'initialMargin': '21.87253418',
#   'maintMargin': '0.08749013',
#   'positionInitialMargin': '21.87253418',
#   'openOrderInitialMargin': '0',
#   'adl': 1,
#   'bidNotional': '0',
#   'askNotional': '0',
#   'updateTime': 1778407588831}]

# %%
import pandas as pd
pos_list=[]
for p in pos:
    pos_list.append(dict(p))
df=pd.DataFrame(pos_list)
df
# Out:
#     symbol positionSide positionAmt entryPrice breakEvenPrice      markPrice  \
# 0  ETHUSDT         BOTH       0.010    2324.24     2325.40212  2187.25341860
#
#   unRealizedProfit liquidationPrice isolatedMargin     notional marginAsset  \
# 0      -1.36986581                0              0  21.87253418        USDT
#
#   isolatedWallet initialMargin maintMargin positionInitialMargin  \
# 0              0   21.87253418  0.08749013           21.87253418
#
#   openOrderInitialMargin  adl bidNotional askNotional     updateTime
# 0                      0    1           0           0  1778407588831

# %%
ord=client.futures_get_open_orders(symbol='SOLUSDT')
ord
# Out:
# []
