# %%
from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager

api_key=''
api_secret=''
client = Client(api_key, api_secret)



info = client.get_account()
info

# %%
balance = client.futures_account()
balance
# Out:
# {'feeTier': 0,
#  'canTrade': True,
#  'canDeposit': True,
#  'canWithdraw': True,
#  'feeBurn': True,
#  'tradeGroupId': -1,
#  'updateTime': 0,
#  'multiAssetsMargin': False,
#  'totalInitialMargin': '0.00000000',
#  'totalMaintMargin': '0.00000000',
#  'totalWalletBalance': '278.63846283',
#  'totalUnrealizedProfit': '0.00000000',
#  'totalMarginBalance': '278.63846283',
#  'totalPositionInitialMargin': '0.00000000',
#  'totalOpenOrderInitialMargin': '0.00000000',
#  'totalCrossWalletBalance': '278.63846283',
#  'totalCrossUnPnl': '0.00000000',
#  'availableBalance': '278.63846283',
#  'maxWithdrawAmount': '278.63846283',
#  'assets': [{'asset': 'FDUSD',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'U',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'LDUSDT',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'BFUSD',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'BNB',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'ETH',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'RWUSD',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'BTC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'USDT',
#    'walletBalance': '278.63846283',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '278.63846283',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '278.63846283',
#    'crossWalletBalance': '278.63846283',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '278.63846283',
#    'marginAvailable': True,
#    'updateTime': 1765755168835},
#   {'asset': 'USD1',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'USDC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0}],
#  'positions': [{'symbol': 'SNTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '200000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CGPTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SUSHIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TRUTHUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1765292848859,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BNTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'STRAXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BANKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'EVAAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MILKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '1000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1764759118638,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MUBARAKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SPELLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'WAVESUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '1200000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XAIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TSLAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MONUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '750000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'PNUTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DARUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '1500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'PENDLEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DEXEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AWEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'RVVUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GLMRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KAIAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SHELLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '800000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1756986104794,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'NIGHTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CHIPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'REZUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '800000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1765274332230,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GRIFFAINUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '800000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '1000BONKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '15000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ESPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TRXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '30000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1765111291901,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MORPHOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FHEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CHILLGUYUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '龙虾USDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BROCCOLI714USDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '10000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1757015773252,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SAPIENUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1764768229117,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SOMIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '59',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '0',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1757272073102,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'EULUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HMSTRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'EPICUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '800000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1765023762503,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '1000BONKUSDC',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BREVUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'POLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '3000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'UMAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OXTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '30000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'APEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AIOTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '800000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1756967577880,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KEYUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SKLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'B2USDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1765291136134,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ZEREBROUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '3000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1757011071717,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'PLUMEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OPENUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ALTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'RECALLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1765180313784,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SKYAIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1764763851569,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'VIRTUALUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MTLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'PROMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1764835450689,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'IPUSDC',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'IDOLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '50',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1756986838415,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CATIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1764786401739,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ETHBTC',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '2000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HUMAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KSMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FORTHUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'PNUTUSDC',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'NXPCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TRBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1765092839363,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MANTRAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MANAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1756751641939,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'IPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '750000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'WUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ONDOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '18000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '2ZUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1764760604894,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'PTBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '60000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'PIPPINUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '21',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1757142680344,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'USDCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '30000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1765270333861,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FORMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'USARUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '10000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KOMAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HANAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1765019836363,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SONICUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '60000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AMDUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '10000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'STMXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '42USDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'INTCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
# ...
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DEGOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '60000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TNSRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BTCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '149',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '300000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1757269324135,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OMGUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '2000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ICXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SUPERUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BASEDUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '1000FLOKIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FTMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '3000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HOODUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '10000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AMBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SPXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'QUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'UAIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1764767744118,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GUAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '60000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GAIBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TROYUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '2000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XEMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '1000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'WLDUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '15000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HOLOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ASTERUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '7500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'WCTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1764825907268,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BROCCOLIF3BUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AZTECUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DMCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BLESSUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1765037336676,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DYDXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OCEANUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'WLDUSDC',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '59',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SANTOSUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DUSKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '1',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '12500000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 1764786401740,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CTSIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '5',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '125000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SUNUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '50',
#    'isolated': True,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'}]}
